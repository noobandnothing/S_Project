# %%
import cv2
import numpy as np
import os
import glob

# %%
def enhance_image_with_clahe(img_path, output_dir):
    """
    Apply CLAHE enhancement to a single image
    """
    try:
        # Load the image in color
        img = cv2.imread(img_path)
        if img is None:
            print(f"Could not load image: {img_path}")
            return False
        
        # Convert from BGR (OpenCV default) to RGB
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Split into R, G, B channels
        r, g, b = cv2.split(img_rgb)
        
        # Create CLAHE object
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        
        # Apply CLAHE per channel
        r_clahe = clahe.apply(r)
        g_clahe = clahe.apply(g)
        b_clahe = clahe.apply(b)
        
        cleaned_rgb = cv2.merge([r_clahe, g_clahe, b_clahe])
        
        # Crop borders slightly to avoid edge artifacts (optional)
        height, width, _ = cleaned_rgb.shape
        cropped = cleaned_rgb[250:height-150, 100:width-50]
        
        # Convert back to BGR for saving with OpenCV
        output_img = cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR)
        
        # Create output filename
        base_name = os.path.splitext(os.path.basename(img_path))[0]
        output_path = os.path.join(output_dir, f"{base_name}_enhanced.png")
        
        # Save the result
        cv2.imwrite(output_path, output_img)
        print(f"Enhanced: {img_path} -> {output_path}")
        return True
        
    except Exception as e:
        print(f"Error processing {img_path}: {str(e)}")
        return False

# %%
input_dir = '/home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/'
output_dir = '/home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/'

# %%
os.makedirs(output_dir, exist_ok=True)

# Get all PNG files in the input directory
png_files = glob.glob(os.path.join(input_dir, '*.png'))

# %%
if not png_files:
    print(f"No PNG files found in {input_dir}")
else:
    print(f"Found {len(png_files)} PNG files to process")
    
    # Process each image
    success_count = 0
    for img_path in png_files:
        if enhance_image_with_clahe(img_path, output_dir):
            success_count += 1
    
    print(f"\nProcessing complete: {success_count}/{len(png_files)} images enhanced successfully")
    print(f"Enhanced images saved to: {output_dir}")
# Out:
# Found 80 PNG files to process
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/15_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/72_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/76_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/12_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/1_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/32_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/56_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/80_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/63_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/31_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/33_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/68_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/55_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/74_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/5_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/45_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/37_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/25_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/59_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/8_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/8_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/36_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/75_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/60_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/44_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/64_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/79_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/24_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/24_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/9_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/22_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/54_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/6_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/51_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/48_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/48_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/43_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/16_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/34_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/50_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/11_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/11_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/4_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/77_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/67_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/52_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/71_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/62_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/27_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/18_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/53_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/29_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/29_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/26_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/49_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/39_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/20_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/61_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/46_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/41_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/30_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/17_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/10_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/10_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/21_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/23_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/3_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/78_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/57_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/19_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/73_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/65_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/66_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/40_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/38_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/2_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/14_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/47_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/58_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/13_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/69_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/35_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/42_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Enhanced: /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/70_exact_shape.png -> /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/70_exact_shape_enhanced.png
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/7_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Error processing /home/noob/koty/new_before_last/project-ano/model_deployment/cropped_outputs/28_exact_shape.png: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# Processing complete: 7/80 images enhanced successfully
# Enhanced images saved to: /home/noob/koty/new_before_last/project-ano/predictions-stage2/enhanced/
